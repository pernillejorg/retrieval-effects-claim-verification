# %%
from google.colab import drive
drive.mount('/content/drive')
print("Drive mounted.")

#creating a folder in the Drive specifically for this thesis project
import os

#setting the HuggingFace token so datasets can be downloaded
os.environ["HF_TOKEN"] = "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"
# Out:
# Mounted at /content/drive
# Drive mounted.

# %%
# !git clone https://pernillejorg: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@github.com/pernillejorg/rag-claim-verification.git
# %cd rag-claim-verification
# !git checkout step2.1-baseline-model
# Out:
# Cloning into 'rag-claim-verification'...
# remote: Enumerating objects: 359, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (128/128), done.
# remote: Total 359 (delta 93), reused 126 (delta 42), pack-reused 180 (from 1)
# Receiving objects: 100% (359/359), 167.63 KiB | 5.08 MiB/s, done.
# Resolving deltas: 100% (182/182), done.
# /content/rag-claim-verification
# Branch 'step2.1-baseline-model' set up to track remote branch 'step2.1-baseline-model' from 'origin'.
# Switched to a new branch 'step2.1-baseline-model'

# %%
# !pip install -r requirements.txt -q
# !pip install rank-bm25 sentence-transformers -q
# !pip install "datasets==2.21.0" -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.5/18.5 MB 128.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 124.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 139.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 135.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.8/910.8 kB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 kB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 6.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 7.3.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.18.2, but you have jupyter-server 2.20.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.9.1 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires notebook<7.0,>=5.7.6, but you have notebook 7.6.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 37.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 20.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.6.1 which is incompatible.

# %%
import datasets
print("datasets version:", datasets.__version__)
# Out:
# datasets version: 2.21.0

# %%
from data.utils import load_scifact
claims, _ = load_scifact(split="validation")
print("unique claims:", len(claims))
# Out:
# Downloading builder script:   0%|          | 0.00/7.92k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.33k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.06k [00:00<?, ?B/s]
# The repository for allenai/scifact contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/allenai/scifact.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data:   0%|          | 0.00/3.12M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1261 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/300 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/450 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/5183 [00:00<?, ? examples/s]
# unique claims: 300

# %%
import os, shutil
target = '/content/rag-claim-verification/data/scifact_open/cache'
os.makedirs(target, exist_ok=True)
source = '/content/drive/MyDrive/rag-thesis/data/scifact_open/cache'
for fname in os.listdir(source):
    shutil.copy(os.path.join(source, fname), os.path.join(target, fname))
    print(f"copied {fname}")
print("SciFact-Open cache in place.")
# Out:
# copied corpus_candidates.jsonl
# copied claims_metadata.jsonl
# copied claims.jsonl
# copied corpus.jsonl
# SciFact-Open cache in place.

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
# !mkdir -p results
#SciFact (small corpus, fast)
# !python models/retrieval.py --dataset scifact 2>&1 | tee results/retrieval_scifact_mpnet_log.txt

#SciFact-Open (full 500K corpus -- this is the slow one, ~encoding + retrieval)
# !python models/retrieval.py --dataset scifact_open 2>&1 | tee results/retrieval_scifact_open_mpnet_log.txt
# Out:
# ============================================================
#   Retrieval Evaluation -- SCIFACT
# ============================================================
#
# Validation claims : 300
# Corpus size       : 5183 documents
#
# Claims with evidence (non-NEI): 300
# NEI claims (excluded from Recall@k): 0
#
# --- BM25 Retrieval ---
# Building BM25 index over 5183 documents...
# BM25 index built successfully.
#
# Running BM25 retrieval...
#   Retrieving for claim 1 / 300...
#   Retrieving for claim 101 / 300...
#   Retrieving for claim 201 / 300...
#
# --- Dense Retrieval ---
# Loading dense retrieval model: sentence-transformers/all-mpnet-base-v2
# Using device: cuda
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 5856.03it/s]
# Encoding 5183 documents into dense vectors...
# (This happens once per corpus -- subsequent retrievals are fast)
# Batches: 100%|██████████| 81/81 [00:25<00:00,  3.23it/s]
# Corpus encoded. Embedding matrix shape: (5183, 768)
#
# Running dense retrieval...
#   Retrieving for claim 1 / 300...
#   Retrieving for claim 101 / 300...
#   Retrieving for claim 201 / 300...
#
# ==================================================
#   Retrieval Recall@k -- SCIFACT (validation)
# ==================================================
#   Method                  R@1    R@5   R@10
#   --------------------------------------
#   BM25                  0.437  0.630  0.703
#   Dense                 0.533  0.733  0.803
# ==================================================
#
# Recall@k summary saved to /content/rag-claim-verification/models/../results/retrieval_recall_mpnet_scifact.json
# Retrieved candidates saved to /content/rag-claim-verification/models/../results/retrieval_candidates_mpnet_scifact.json
#
# ============================================================
#   Retrieval Evaluation -- SCIFACT_OPEN
# ============================================================
#
# [load_scifact_open] 279 claims loaded (15 had conflicting SUPPORT/CONTRADICT evidence, resolved to SUPPORT).
# Validation claims : 279
# Corpus size       : 500000 documents
#
# Claims with evidence (non-NEI): 206
# NEI claims (excluded from Recall@k): 73
#
# --- BM25 Retrieval ---
# Building BM25 index over 500000 documents...
# BM25 index built successfully.
#
# Running BM25 retrieval...
#   Retrieving for claim 1 / 279...
#   Retrieving for claim 101 / 279...
#   Retrieving for claim 201 / 279...
#
# --- Dense Retrieval ---
# Loading dense retrieval model: sentence-transformers/all-mpnet-base-v2
# Using device: cuda
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 4194.62it/s]
# Encoding 500000 documents into dense vectors...
# (This happens once per corpus -- subsequent retrievals are fast)
# Batches: 100%|██████████| 7813/7813 [38:21<00:00,  3.39it/s]
# Corpus encoded. Embedding matrix shape: (500000, 768)
#
# Running dense retrieval...
#   Retrieving for claim 1 / 279...
#   Retrieving for claim 101 / 279...
#   Retrieving for claim 201 / 279...
#
# ==================================================
#   Retrieval Recall@k -- SCIFACT_OPEN (validation)
# ==================================================
#   Method                  R@1    R@5   R@10
#   --------------------------------------
#   BM25                  0.403  0.578  0.650
#   Dense                 0.408  0.699  0.752
# ==================================================
#
# Recall@k summary saved to /content/rag-claim-verification/models/../results/retrieval_recall_mpnet_scifact_open.json
# Retrieved candidates saved to /content/rag-claim-verification/models/../results/retrieval_candidates_mpnet_scifact_open.json

# %%
#saving to drive 
import shutil, os
os.makedirs('/content/drive/MyDrive/rag-thesis/results', exist_ok=True)
shutil.copytree(
    '/content/rag-claim-verification/results',
    '/content/drive/MyDrive/rag-thesis/results',
    dirs_exist_ok=True
)
print("Results copied to Drive.")

#confirming the important files landed
import os
for f in os.listdir('/content/drive/MyDrive/rag-thesis/results'):
    print(" ", f)
# Out:
# Results copied to Drive.
#   retrieval_recall_scifact.json
#   retrieval_candidates_scifact.json
#   retrieval_scifact_open_log.txt
#   retrieval_candidates_scifact_open.json
#   retrieval_scifact_log.txt
#   retrieval_recall_scifact_open.json
#   retrieval_recall_mpnet_scifact.json
#   retrieval_recall_mpnet_scifact_open.json
#   experiments_results.md
#   pipeline_results.md
#   reranking_dense_results.md
#   retrieval_sciclaimhunt_results.md
#   retrieval_scifact_mpnet_log.txt
#   baseline_sciclaimhunt_results.md
#   baseline_scifact_results.md
#   retrieval_scifact_open_mpnet_log.txt
#   retrieval_scifact_results.md
#   first_results
#   rerank_scifact_soft_log.txt
#   rerank_scifact_hard_log.txt
#   rerank_scifact_open_soft_log.txt
#   rerank_scifact_open_hard_log.txt
#   retrieval_candidates_mpnet_scifact_open.json
#   retrieval_candidates_mpnet_scifact.json
#   baseline_scifact.json
#   baseline_results.md
#   baseline_scifact_open.json
#   baseline_scifact_open_log.txt
#   retrieval_results.md
#   baseline_scifact_log.txt
